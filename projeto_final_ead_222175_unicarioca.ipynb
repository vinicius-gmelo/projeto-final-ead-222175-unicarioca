# %% [markdown]
# <a href="https://colab.research.google.com/github/vinicius-gmelo/projeto-final-ead-222175-unicarioca/blob/main/projeto_final_ead_222175_unicarioca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Projeto final da disciplina "EAD222175 - _PARADIGMAS DE LINGUAGENS DE PROGRAMAÇÃO EM PYTHON 2022/2"

# %% [markdown]
# * Aluno: Vinicius Gonçalves Melo
# * Matrícula: 2022200182
# * Curso: Desenvolvimento de Software Multiplataforma - Unicarioca
# * Data: 18/11/2022

# %% [markdown]
# 1. Importar os pacotes “pandas”, “matplotlib” e “seaborn”.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. Apresente um descrito do repositório de dados: 'http://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data'

# %%
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data', skiprows=2)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 210 entries, BRICKFACE to GRASS
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   REGION-CENTROID-COL   210 non-null    float64
#  1   REGION-CENTROID-ROW   210 non-null    float64
#  2   REGION-PIXEL-COUNT    210 non-null    int64
#  3   SHORT-LINE-DENSITY-5  210 non-null    float64
#  4   SHORT-LINE-DENSITY-2  210 non-null    float64
#  5   VEDGE-MEAN            210 non-null    float64
#  6   VEDGE-SD              210 non-null    float64
#  7   HEDGE-MEAN            210 non-null    float64
#  8   HEDGE-SD              210 non-null    float64
#  9   INTENSITY-MEAN        210 non-null    float64
#  10  RAWRED-MEAN           210 non-null    float64
#  11  RAWBLUE-MEAN          210 non-null    float64
#  12  RAWGREEN-MEAN         210 non-null    float64
#  13  EXRED-MEAN            210 non-null    float64
# ...

# %% [markdown]
# 3. Importe os dados do repositório do item 2 em um Dataframe.

# %%
df = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/image/segmentation.data', skiprows=2)
df
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                   9
# BRICKFACE                188.0                133.0                   9
# BRICKFACE                105.0                139.0                   9
# BRICKFACE                 34.0                137.0                   9
# BRICKFACE                 39.0                111.0                   9
# ...                        ...                  ...                 ...
# GRASS                     36.0                243.0                   9
# GRASS                    186.0                218.0                   9
# GRASS                    197.0                236.0                   9
# GRASS                    208.0                240.0                   9
# GRASS                    223.0                185.0                   9
#
#            SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# ...

# %% [markdown]
# 4. Apresente os 5 primeiros registros do Dataframe do item 3.

# %%
df.head(5)
# Out:
#            REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# BRICKFACE                140.0                125.0                   9
# BRICKFACE                188.0                133.0                   9
# BRICKFACE                105.0                139.0                   9
# BRICKFACE                 34.0                137.0                   9
# BRICKFACE                 39.0                111.0                   9
#
#            SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN  VEDGE-SD  \
# BRICKFACE                   0.0                   0.0    0.277778  0.062963
# BRICKFACE                   0.0                   0.0    0.333333  0.266667
# BRICKFACE                   0.0                   0.0    0.277778  0.107407
# BRICKFACE                   0.0                   0.0    0.500000  0.166667
# BRICKFACE                   0.0                   0.0    0.722222  0.374074
#
# ...

# %% [markdown]
# 5. Apresente as colunas do Dataframe do item 3.

# %%
df.columns.tolist()
# Out:
# ['REGION-CENTROID-COL',
#  'REGION-CENTROID-ROW',
#  'REGION-PIXEL-COUNT',
#  'SHORT-LINE-DENSITY-5',
#  'SHORT-LINE-DENSITY-2',
#  'VEDGE-MEAN',
#  'VEDGE-SD',
#  'HEDGE-MEAN',
#  'HEDGE-SD',
#  'INTENSITY-MEAN',
#  'RAWRED-MEAN',
#  'RAWBLUE-MEAN',
#  'RAWGREEN-MEAN',
#  'EXRED-MEAN',
#  'EXBLUE-MEAN',
#  'EXGREEN-MEAN',
#  'VALUE-MEAN',
#  'SATURATION-MEAN',
#  'HUE-MEAN']

# %% [markdown]
# 6. Apresente os tipos de dados das colunas do Dataframe do item 3.

# %%
df.dtypes
# Out:
# REGION-CENTROID-COL     float64
# REGION-CENTROID-ROW     float64
# REGION-PIXEL-COUNT        int64
# SHORT-LINE-DENSITY-5    float64
# SHORT-LINE-DENSITY-2    float64
# VEDGE-MEAN              float64
# VEDGE-SD                float64
# HEDGE-MEAN              float64
# HEDGE-SD                float64
# INTENSITY-MEAN          float64
# RAWRED-MEAN             float64
# RAWBLUE-MEAN            float64
# RAWGREEN-MEAN           float64
# EXRED-MEAN              float64
# EXBLUE-MEAN             float64
# EXGREEN-MEAN            float64
# VALUE-MEAN              float64
# SATURATION-MEAN         float64
# HUE-MEAN                float64
# dtype: object

# %% [markdown]
# 7. Apresente uma análise exploratória dos dados do Dataframe do item 3 (dica: utilize a função “describe”).

# %%
df.describe()
# Out:
#        REGION-CENTROID-COL  REGION-CENTROID-ROW  REGION-PIXEL-COUNT  \
# count           210.000000           210.000000               210.0
# mean            124.647619           122.757143                 9.0
# std              74.104024            58.139686                 0.0
# min               1.000000            11.000000                 9.0
# 25%              60.500000            81.500000                 9.0
# 50%             123.500000           121.500000                 9.0
# 75%             189.750000           174.500000                 9.0
# max             252.000000           250.000000                 9.0
#
#        SHORT-LINE-DENSITY-5  SHORT-LINE-DENSITY-2  VEDGE-MEAN    VEDGE-SD  \
# count            210.000000            210.000000  210.000000  210.000000
# mean               0.008466              0.006349    1.925132    5.719529
# std                0.029549              0.030077    3.158211   43.495942
# ...

# %% [markdown]
# 8. Selecione uma das características do Dataframe e exclua os dados NA.

# %%
value_mean = df[['VALUE-MEAN']].dropna()
value_mean

# df1 = df.dropna(subset=['VALUE-MEAN']) para excluir os dados NA e retornar um dataframe
# df.dropna(subset=['VALUE-MEAN'], inplace=True) para excluir os dados NA mudando o dataframe original
# Out:
#            VALUE-MEAN
# BRICKFACE    7.777778
# BRICKFACE    8.444445
# BRICKFACE    7.555555
# BRICKFACE    7.777778
# BRICKFACE    7.888889
# ...               ...
# GRASS       18.000000
# GRASS       17.777779
# GRASS       18.555555
# GRASS       18.555555
# GRASS       17.555555
#
# [210 rows x 1 columns]

# %% [markdown]
# 9. Apresente o histograma dos dados do item 8.

# %%
value_mean.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f15a46efa50>]],
#       dtype=object)

# %% [markdown]
# ## 10. Apresente uma conclusão do seu trabalho.

# %% [markdown]
# É impressionante a facilidade com que se consegue manipular e representar dados essas bibliotecas do Python. Já considero Python uma linguagem que facilita muito as coisas, estando mais habituado a linguagens como PHP e Ruby. Achei prático o uso de hashes para a representação de colunas/linhas pela Pandas. Além disso, não conhecia o Google Colab, que se mostrou uma ferramenta bastante prática para apresentações (gostaria de saber se há ambientes em nuvem de desenvolvimento/apresentação para outras linguagens...).
